# %%
from flask import Flask , render_template , request , jsonify
from bs4 import BeautifulSoup as bs 
from urllib.request import urlopen as urReq

# %%
in_url="https://halloffame.ineuron.ai"

# %%
in_url
# Out:
# 'https://halloffame.ineuron.ai'

# %%
response_web=urReq(in_url)

# %%
data_url=response_web.read()

# %%
buti_html=bs(data_url,"html.parser")

# %%
buti_html
# Out:
# <!DOCTYPE html>
# ...

# %%
buti_html.find_all("div", {"class":"Students_students__card__5PCSn"})
# Out:
# []
